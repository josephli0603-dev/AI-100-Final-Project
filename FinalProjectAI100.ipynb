# %% [markdown]
# **Original Code:**

# %%
# ================================
# 1. Import Libraries
# ================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset_500_rows.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5885 - loss: 0.6351 - val_accuracy: 0.8500 - val_loss: 0.4958
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7888 - loss: 0.5561 - val_accuracy: 0.8750 - val_loss: 0.4279
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8411 - loss: 0.4767 - val_accuracy: 0.8750 - val_loss: 0.3981
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8326 - loss: 0.4662 - val_accuracy: 0.8750 - val_loss: 0.3928
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8427 - loss: 0.4148 - val_accuracy: 0.8750 - val_loss: 0.3921
# Epoch 6/50
# ...

# %% [markdown]
# Case 1:

# %%
# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset_500_rows.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4611/2348116701.py in <cell line: 0>()
#       3 # ================================
#       4 file_path = "binary_classification_dataset_500_rows.csv"
# ----> 5 df = pd.read_csv(file_path)
#       6
#       7 # Separate features and target
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Case 2:

# %%
# ================================
# 1. Import Libraries
# ================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7315/4240728284.py in <cell line: 0>()
#      15 # ================================
#      16 file_path = "binary_classification_dataset.csv"
# ---> 17 df = pd.read_csv(file_path)
#      18
#      19 # Separate features and target
#
# ...

# %% [markdown]
# Case 3:

# %%
# ================================
# 1. Import Libraries
# ================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset_500_rows.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# /tmp/ipykernel_985/694231221.py in <cell line: 0>()
#      24 # 3. Train/Test Split (80/20)
#      25 # ================================
# ---> 26 X_train, X_test, y_train, y_test = train_test_split(
#      27     X, y, test_size=0, random_state=42, stratify=y
#      28 )
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     204             params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
#     205
# --> 206             validate_parameter_constraints(
#     207                 parameter_constraints, params, caller_name=func.__qualname__
#     208             )
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      96                 )
# ...

# %% [markdown]
# Case 4:

# %%
# ================================
# 1. Import Libraries
# ================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset_500_rows.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_985/2370566200.py in <cell line: 0>()
#      32 # ================================
#      33 scaler = StandardScaler()
# ---> 34 X_train = scaler.transform(X_train)
#      35 X_test = scaler.transform(X_test)
#      36
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#    1057             Transformed array.
#    1058         """
# -> 1059         check_is_fitted(self)
#    1060
# ...

# %% [markdown]
# Case 5:

# %%
# ================================
# 1. Import Libraries
# ================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset_500_rows.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='hi')  # Binary classification
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_985/1826650314.py in <cell line: 0>()
#      42     Dense(16, activation='relu'),
#      43     Dense(8, activation='relu'),
# ---> 44     Dense(1, activation='hi')  # Binary classification
#      45 ])
#      46
#
# ...

# %% [markdown]
# Case 6:

# %%
# ================================
# 1. Import Libraries
# ================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset_500_rows.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(0, activation='sigmoid')  # Binary classification
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_985/422736634.py in <cell line: 0>()
#      42     Dense(16, activation='relu'),
#      43     Dense(8, activation='relu'),
# ---> 44     Dense(0, activation='sigmoid')  # Binary classification
#      45 ])
#      46
#
# ...

# %% [markdown]
# Case 7:

# %%
# ================================
# 1. Import Libraries
# ================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset_500_rows.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])



# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_985/2383243522.py in <cell line: 0>()
#      50 # 6. Train Model
#      51 # ================================
# ---> 52 model.fit(
#      53     X_train, y_train,
#      54     epochs=50,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# ...

# %% [markdown]
# Case 8:

# %%
# ================================
# 1. Import Libraries
# ================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset_500_rows.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(
    optimizer='steve',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_985/1206058645.py in <cell line: 0>()
#      45 ])
#      46
# ---> 47 model.compile(
#      48     optimizer='steve',
#      49     loss='binary_crossentropy',
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
# ...

# %% [markdown]
# Case 9:

# %%
# ================================
# 1. Import Libraries
# ================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset_500_rows.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=-16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_985/1037942147.py in <cell line: 0>()
#      54 # 6. Train Model
#      55 # ================================
# ---> 56 model.fit(
#      57     X_train, y_train,
#      58     epochs=50,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# ...

# %% [markdown]
# Case 10:

# %%
# ================================
# 1. Import Libraries
# ================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ================================
# 2. Load Dataset
# ================================
file_path = "binary_classification_dataset_500_rows.csv"
df = pd.read_csv(file_path)

# Separate features and target
X = df.drop("loan_default", axis=1)
y = df["loan_default"]

# ================================
# 3. Train/Test Split (80/20)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# ================================
# 4. Feature Scaling
# ================================
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ================================
# 5. Build Deep Learning Model
# ================================
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ================================
# 6. Train Model
# ================================
model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    verbose=1
)

# ================================
# 7. Evaluate Model
# ================================
y_pred_prob = model.predict(y_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Recall for Default Class (1)
recall_default = recall_score(y_test, y_pred, pos_label=1)

# ================================
# 8. Print Results
# ================================
print("Confusion Matrix:")
print(cm)

print("\nAccuracy Score:", accuracy)
print("Recall Score (Default Class = 1):", recall_default)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6250 - loss: 0.6743 - val_accuracy: 0.8750 - val_loss: 0.6214
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8250 - loss: 0.5759 - val_accuracy: 0.8750 - val_loss: 0.5328
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8250 - loss: 0.5045 - val_accuracy: 0.8750 - val_loss: 0.4647
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8250 - loss: 0.4602 - val_accuracy: 0.8750 - val_loss: 0.4212
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8250 - loss: 0.4335 - val_accuracy: 0.8750 - val_loss: 0.4043
# ...
